# %% [markdown]
# # COVID-19 - Exploratory Data Analysis
# ### Level - Begginer

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
print(os.listdir('C:\\Users\\rossetron\\EDA_Video_Projects\\vid-7-pandas'))

# Any results you write to the current directory are saved as output.
# Out:
# ['.ipynb_checkpoints', 'Covid-19 - Key Insights through Exploration of Data.ipynb', 'uncover']

# %%
data = pd.read_csv('uncover/UNCOVER/harvard_global_health_institute/hospital-capacity-by-state-20-population-contracted.csv')

# %% [markdown]
# # **PANDAS**
# * single column = series
# * NaN = not a number
# * dataframevalues = numpy
#
# # **BUILDING DATAFRAMES FROM SCRATCH**
# * We can build dataframes from csv.
# * Also we can build dataframe from dictionaries.
#
#   zip() method: This funtions return a lisst of tuples, where the i-th tuple contains the i-th element from each of the argument sequences or iterables.
# * Adding new column.
#
# ***Broadcasting: *** Create new column and assig a value to entire column.

# %%
# dataframe from dictionary
country = ["France", "Turkey", "Germany", "Spain"]
population = ["15", "20", "32", "50"]
list_label = ["country", "population"]
list_col = [country, population]
zipped = list(zip(list_label, list_col))
data_dict=dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#    country population
# 0   France         15
# 1   Turkey         20
# 2  Germany         32
# 3    Spain         50

# %%
### Add new columns
df["capital"] = ["Paris", "Ankara", "Berlin", "Madrid"]
df
# Out:
#    country population capital
# 0   France         15   Paris
# 1   Turkey         20  Ankara
# 2  Germany         32  Berlin
# 3    Spain         50  Madrid

# %%
#broadcasting
df["income"]=0#broadcasting entire column
df
# Out:
#    country population capital  income
# 0   France         15   Paris       0
# 1   Turkey         20  Ankara       0
# 2  Germany         32  Berlin       0
# 3    Spain         50  Madrid       0

# %% [markdown]
# ### **VIRTUAL EXPLORATORY DATA ANALYSIS**
# * Plot
# * Subplot
# * Histogram
#   bins = number of bins
#   range(tuple) = min and max values of data
#   normed(boolean) = normalize or not
#   cumulative(boolean) = compute cumulative distribution

# %%
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 38 columns):
# state                                                                  53 non-null object
# total_hospital_beds                                                    52 non-null float64
# total_icu_beds                                                         52 non-null float64
# hospital_bed_occupancy_rate                                            52 non-null float64
# icu_bed_occupancy_rate                                                 52 non-null float64
# available_hospital_beds                                                52 non-null float64
# potentially_available_hospital_beds                                    52 non-null float64
# available_icu_beds                                                     52 non-null float64
# potentially_available_icu_beds                                         52 non-null float64
# adult_population                                                       52 non-null float64
# population_65                                                          52 non-null float64
# projected_infected_individuals                                         52 non-null float64
# proejcted_hospitalized_individuals                                     52 non-null float64
# projected_individuals_needing_icu_care                                 52 non-null float64
# hospital_beds_needed_six_months                                        52 non-null float64
# percentage_of_available_beds_needed_six_months                         52 non-null float64
# percentage_of_potentially_available_beds_needed_six_months             52 non-null float64
# percentage_of_total_beds_needed_six_months                             52 non-null float64
# hospital_beds_needed_twelve_months                                     52 non-null float64
# percentage_of_available_beds_needed_twelve_months                      52 non-null float64
# percentage_of_potentially_available_beds_needed_twelve_months          52 non-null float64
# percentage_of_total_beds_needed_twelve_months                          52 non-null float64
# hospital_beds_needed_eighteen_months                                   52 non-null float64
# percentage_of_available_beds_needed_eighteen_months                    52 non-null float64
# percentage_of_potentially_available_beds_needed_eighteen_months        52 non-null float64
# percentage_of_total_beds_needed_eighteen_months                        52 non-null float64
# icu_beds_needed_six_months                                             52 non-null float64
# percentage_of_available_icu_beds_needed_six_months                     52 non-null float64
# percentage_of_potentially_available_icu_beds_needed_six_months         52 non-null float64
# percentage_of_total_icu_beds_needed_six_months                         52 non-null float64
# icu_beds_needed_twelve_months                                          52 non-null float64
# percentage_of_available_icu_beds_needed_twelve_months                  52 non-null float64
# percentage_of_potentially_available_icu_beds_needed_twelve_months      52 non-null float64
# percentage_of_total_icu_beds_needed_twelve_months                      52 non-null float64
# icu_beds_needed_eighteen_months                                        52 non-null float64
# percentage_of_available_icu_beds_needed_eighteen_months                52 non-null float64
# percentage_of_potentially_available_icu_beds_needed_eighteen_months    52 non-null float64
# percentage_of_total_icu_beds_needed_eighteen_months                    52 non-null float64
# dtypes: float64(37), object(1)
# memory usage: 16.2+ KB

# %%
data.head()
# Out:
#   state  total_hospital_beds  total_icu_beds  hospital_bed_occupancy_rate  \
# 0    AK               1583.0           130.0                         0.66
# 1    AL              13959.0          1870.0                         0.64
# 2    AR               8428.0           856.0                         0.52
# 3    AZ              12868.0          1742.0                         0.62
# 4    CA              68554.0          8131.0                         0.67
#
#    icu_bed_occupancy_rate  available_hospital_beds  \
# 0                    0.58                    533.0
# 1                    0.68                   4994.0
# 2                    0.58                   4069.0
# 3                    0.53                   4938.0
# 4                    0.58                  22831.0
#
#    potentially_available_hospital_beds  available_icu_beds  \
# 0                               1058.0                55.0
# 1                               9476.0               606.0
# 2                               6248.0               362.0
# 3                               8903.0               814.0
# 4                              45692.0              3381.0
#
#    potentially_available_icu_beds  adult_population  ...  \
# 0                            93.0          552319.0  ...
# 1                          1238.0         3748089.0  ...
# 2                           609.0         2272226.0  ...
# 3                          1278.0         5187520.0  ...
# 4                          5756.0        29868127.0  ...
#
#    percentage_of_potentially_available_icu_beds_needed_six_months  \
# 0                                               3.34
# 1                                               1.83
# 2                                               2.27
# 3                                               2.47
# 4                                               3.04
#
#    percentage_of_total_icu_beds_needed_six_months  \
# 0                                            2.39
# 1                                            1.21
# 2                                            1.61
# 3                                            1.82
# 4                                            2.15
#
#    icu_beds_needed_twelve_months  \
# 0                          155.0
# 1                         1131.0
# 2                          690.0
# 3                         1581.0
# 4                         8737.0
#
#    percentage_of_available_icu_beds_needed_twelve_months  \
# 0                                               2.82
# 1                                               1.87
# 2                                               1.91
# 3                                               1.94
# 4                                               2.58
#
#    percentage_of_potentially_available_icu_beds_needed_twelve_months  \
# 0                                               1.67
# 1                                               0.91
# 2                                               1.13
# 3                                               1.24
# 4                                               1.52
#
#    percentage_of_total_icu_beds_needed_twelve_months  \
# 0                                               1.19
# 1                                               0.60
# 2                                               0.81
# 3                                               0.91
# 4                                               1.07
#
#    icu_beds_needed_eighteen_months  \
# 0                            101.0
# 1                            738.0
# 2                            450.0
# 3                           1031.0
# 4                           5698.0
#
#    percentage_of_available_icu_beds_needed_eighteen_months  \
# 0                                               1.84
# 1                                               1.22
# 2                                               1.24
# 3                                               1.27
# 4                                               1.69
#
#    percentage_of_potentially_available_icu_beds_needed_eighteen_months  \
# 0                                               1.09
# 1                                               0.60
# 2                                               0.74
# 3                                               0.81
# 4                                               0.99
#
#    percentage_of_total_icu_beds_needed_eighteen_months
# 0                                               0.78
# 1                                               0.39
# 2                                               0.53
# 3                                               0.59
# 4                                               0.70
#
# [5 rows x 38 columns]

# %%
#Plotting all data
data1 = data.loc[:,["total_hospital_beds", "available_hospital_beds", "potentially_available_hospital_beds"]]
data1.plot()

#For another column
data2 = data.loc[:,["percentage_of_potentially_available_icu_beds_needed_six_months", "percentage_of_potentially_available_icu_beds_needed_twelve_months", "percentage_of_potentially_available_icu_beds_needed_eighteen_months"]]
data2.plot()

# %%
#Subplots
data1.plot(subplots=True)
plt.show()

data2.plot(subplots=True)
plt.show()

# %%
### Scatter plot
data.plot(kind = "scatter", x="available_icu_beds", y = "potentially_available_icu_beds")
plt.show()

# %%
#Hist plot (measure the frequency)
data.plot(kind = "hist", y = "potentially_available_icu_beds", bins = 50, range = (0, 250))

# %%
#Histogram subplot with non cumulative and cumulative
fig, axes = plt.subplots(nrows = 2, ncols = 1)
data.plot(kind = "hist", y = "potentially_available_icu_beds", bins = 50, range = (0, 250),  ax = axes[0])
data.plot(kind = "hist", y = "potentially_available_icu_beds", bins = 50, range = (0, 250),  ax = axes[1], cumulative = True)
plt.savefig('graph.png')
plt

#For another column
fig, axes = plt.subplots(nrows = 2, ncols = 1)
data.plot(kind = "hist", y = "available_icu_beds", bins = 50, range = (0, 250),  ax = axes[0])
data.plot(kind = "hist", y = "available_icu_beds", bins = 50, range = (0, 250),  ax = axes[1], cumulative = True)
plt.savefig('graph.png')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\rossetron\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
